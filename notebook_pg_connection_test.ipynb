# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
engine.connect()

# %%
query = """select 1 as number;"""
pd.read_sql(query, con=engine)

query = """
    select * from pg_catalog.pg_tables
    where schemaname != 'pg_catalog' and schemaname != 'information_schema';
"""
pd.read_sql(query, con=engine)
# Out:
#   schemaname         tablename tableowner tablespace  hasindexes  hasrules  \
# 0     public  yellow_taxi_data       root       None        True     False
#
#    hastriggers  rowsecurity
# 0        False        False

# %%
query = """
    select * from yellow_taxi_data limit 10
"""
pd.read_sql(query, con=engine)
# Out:
#      index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0  1000000         1  2021-01-25 17:04:55   2021-01-25 17:14:08
# 1  1000001         2  2021-01-25 17:27:41   2021-01-25 17:34:51
# 2  1000002         2  2021-01-25 17:48:51   2021-01-25 18:01:25
# 3  1000003         2  2021-01-25 17:06:14   2021-01-25 17:11:49
# 4  1000004         2  2021-01-25 17:32:27   2021-01-25 17:41:15
# 5  1000005         2  2021-01-25 17:17:29   2021-01-25 17:27:47
# 6  1000006         1  2021-01-25 17:00:53   2021-01-25 17:08:24
# 7  1000007         1  2021-01-25 17:30:59   2021-01-25 17:55:57
# 8  1000008         2  2021-01-25 17:24:09   2021-01-25 17:30:08
# 9  1000009         2  2021-01-25 17:38:44   2021-01-25 17:58:24
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0              1.0           0.90         1.0                  N
# 1              2.0           1.75         1.0                  N
# 2              2.0           1.92         1.0                  N
# 3              1.0           1.03         1.0                  N
# 4              1.0           1.64         1.0                  N
# 5              1.0           1.62         1.0                  N
# 6              1.0           1.40         1.0                  N
# 7              1.0           3.90         1.0                  N
# 8              4.0           1.51         1.0                  N
# 9              5.0           4.10         1.0                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           161           186             1          7.5    3.5      0.5
# 1           162           236             1          7.5    1.0      0.5
# 2           140            43             1         10.0    1.0      0.5
# 3           140           141             1          6.0    1.0      0.5
# 4           162           141             1          8.0    1.0      0.5
# 5           162           100             1          8.5    1.0      0.5
# 6           236           141             1          7.0    3.5      0.5
# 7           140           113             1         18.0    3.5      0.5
# 8           170           113             1          7.0    1.0      0.5
# 9           164           238             1         16.5    1.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0        3.00           0.0                    0.3         14.80
# 1        2.36           0.0                    0.3         14.16
# 2        2.86           0.0                    0.3         17.16
# 3        2.06           0.0                    0.3         12.36
# 4        2.46           0.0                    0.3         14.76
# 5        2.56           0.0                    0.3         15.36
# 6        2.25           0.0                    0.3         13.55
# 7        5.55           0.0                    0.3         27.85
# 8        2.26           0.0                    0.3         13.56
# 9        4.16           0.0                    0.3         24.96
#
#    congestion_surcharge airport_fee
# 0                   2.5        None
# 1                   2.5        None
# 2                   2.5        None
# 3                   2.5        None
# 4                   2.5        None
# 5                   2.5        None
# 6                   2.5        None
# 7                   2.5        None
# 8                   2.5        None
# 9                   2.5        None
